# %% [markdown]
# # The given Neural Network, adapted for our purposes, after it was fixed
#
# This simple classifier consists of a CNN with two convolutional+pooling layers with a soft-max loss
#
# Credits: Aurelien Lucchi, ETH Zürich

# %%
import gzip
import os
import sys
import urllib
import matplotlib.image as mpimg
from sklearn import metrics
from PIL import Image

import code

import tensorflow.python.platform

import numpy
import tensorflow as tf

# %%
NUM_CHANNELS = 3  # RGB images
PIXEL_DEPTH = 255
NUM_LABELS = 2
TRAINING_SIZE = 80
VALIDATION_SIZE = 25  # Size of the validation set.
SEED = 66478  # Set to None for random seed.
BATCH_SIZE = 16 #64
NUM_EPOCHS = 100
RESTORE_MODEL = False  # If True, restore existing model instead of training a new one
RECORDING_STEP = 0

TEST_SIZE = 50

# Set image patch size in pixels
# IMG_PATCH_SIZE should be a multiple of 4
# image size should be an integer multiple of this number!
IMG_PATCH_SIZE = 16

# %%
test_img_dir = 'test_set_images/'
data_dir = 'training/'
train_data_filename = data_dir + 'images/'
train_validation_filename = data_dir + 'validation/'
train_labels_filename = data_dir + 'groundtruth/'

# %%
# Extract patches from a given image
def img_crop(im, w, h):
    list_patches = []
    imgwidth = im.shape[0]
    imgheight = im.shape[1]
    is_2d = len(im.shape) < 3
    for i in range(0, imgheight, h):
        for j in range(0, imgwidth, w):
            if is_2d:
                im_patch = im[j:j+w, i:i+h]
            else:
                im_patch = im[j:j+w, i:i+h, :]
            list_patches.append(im_patch)
    return list_patches


def extract_data(filename, num_images):
    """Extract the images into a 4D tensor [image index, y, x, channels].
    Values are rescaled from [0, 255] down to [-0.5, 0.5].
    """
    print("Loading images")
    imgs = []
    for i in range(1, num_images+1):
        imageid = "satImage_%.3d" % i
        image_filename = filename + imageid + ".png"
        if os.path.isfile(image_filename):
            img = mpimg.imread(image_filename)
            imgs.append(img)
        else:
            print('File ' + image_filename + ' does not exist')

    num_images = len(imgs)
    IMG_WIDTH = imgs[0].shape[0]
    IMG_HEIGHT = imgs[0].shape[1]
    N_PATCHES_PER_IMAGE = (IMG_WIDTH/IMG_PATCH_SIZE)*(IMG_HEIGHT/IMG_PATCH_SIZE)

    img_patches = [img_crop(imgs[i], IMG_PATCH_SIZE, IMG_PATCH_SIZE) for i in range(num_images)]
    data = [img_patches[i][j] for i in range(len(img_patches)) for j in range(len(img_patches[i]))]

    return numpy.asarray(data)


# Assign a label to a patch v
def value_to_class(v):
    foreground_threshold = 0.25  # percentage of pixels > 1 required to assign a foreground label to a patch
    df = numpy.sum(v)
    if df > foreground_threshold:  # road
        return [0, 1]
    else:  # bgrd
        return [1, 0]


# Extract label images
def extract_labels(filename, end_id, start_id=1):
    """Extract the labels into a 1-hot matrix [image index, label index]."""
    gt_imgs = []
    for i in range(start_id, end_id + 1):
        imageid = "satImage_%.3d" % i
        image_filename = filename + imageid + ".png"
        if os.path.isfile(image_filename):
            img = mpimg.imread(image_filename)
            gt_imgs.append(img)
        else:
            print('File ' + image_filename + ' does not exist')

    num_images = len(gt_imgs)
    gt_patches = [img_crop(gt_imgs[i], IMG_PATCH_SIZE, IMG_PATCH_SIZE) for i in range(num_images)]
    data = numpy.asarray([gt_patches[i][j] for i in range(len(gt_patches)) for j in range(len(gt_patches[i]))])
    labels = numpy.asarray([value_to_class(numpy.mean(data[i])) for i in range(len(data))])

    # Convert to dense 1-hot representation.
    return labels.astype(numpy.float32)


def error_rate(predictions, labels):
    """Return the error rate based on dense predictions and 1-hot labels."""
    return 100.0 - (
        100.0 *
        numpy.sum(numpy.argmax(predictions, 1) == numpy.argmax(labels, 1)) /
        predictions.shape[0])

# %%
def load_image(infilename):
    data = mpimg.imread(infilename)
    return data

def binary_to_uint8(img):
    rimg = (img * 255).round().astype(numpy.uint8)
    return rimg

# %%
# Write predictions from neural network to a file
def write_predictions_to_file(predictions, labels, filename):
    max_labels = numpy.argmax(labels, 1)
    max_predictions = numpy.argmax(predictions, 1)
    file = open(filename, "w")
    n = predictions.shape[0]
    for i in range(0, n):
        file.write(max_labels(i) + ' ' + max_predictions(i))
    file.close()

# Convert array of labels to an image
def label_to_img(imgwidth, imgheight, w, h, labels):
    array_labels = numpy.zeros([imgwidth, imgheight])
    idx = 0
    for i in range(0, imgheight, h):
        for j in range(0, imgwidth, w):
            if labels[idx][0] > 0.5:  # bgrd
                l = 0
            else:
                l = 1
            array_labels[j:j+w, i:i+h] = l
            idx = idx + 1
    return array_labels

# %%
tf.app.flags.DEFINE_string('train_dir', '/tmp/segment_aerial_images',
                           """Directory where to write event logs """
                           """and checkpoint.""")
FLAGS = tf.app.flags.FLAGS

def main(argv=None):  # pylint: disable=unused-argument

    # Extract it into numpy arrays.
    train_data = extract_data(train_data_filename, TRAINING_SIZE)
    train_labels = extract_labels(train_labels_filename, TRAINING_SIZE)

    num_epochs = NUM_EPOCHS

    c0 = 0  # bgrd
    c1 = 0  # road
    for i in range(len(train_labels)):
        if train_labels[i][0] == 1:
            c0 = c0 + 1
        else:
            c1 = c1 + 1
    print('Number of data points per class: c0 = ' + str(c0) + ' c1 = ' + str(c1))

    print('Balancing training data...')
    min_c = min(c0, c1)
    idx0 = [i for i, j in enumerate(train_labels) if j[0] == 1]
    idx1 = [i for i, j in enumerate(train_labels) if j[1] == 1]
    new_indices = idx0[0:min_c] + idx1[0:min_c]
    print(len(new_indices))
    print(train_data.shape)
    train_data = train_data[new_indices, :, :, :]
    train_labels = train_labels[new_indices]

    train_size = train_labels.shape[0]

    c0 = 0
    c1 = 0
    for i in range(len(train_labels)):
        if train_labels[i][0] == 1:
            c0 = c0 + 1
        else:
            c1 = c1 + 1
    print('Number of data points per class: c0 = ' + str(c0) + ' c1 = ' + str(c1))

    # This is where training samples and labels are fed to the graph.
    # These placeholder nodes will be fed a batch of training data at each
    # training step using the {feed_dict} argument to the Run() call below.
    train_data_node = tf.placeholder(
        tf.float32,
        shape=(BATCH_SIZE, IMG_PATCH_SIZE, IMG_PATCH_SIZE, NUM_CHANNELS))
    train_labels_node = tf.placeholder(tf.float32,
                                       shape=(BATCH_SIZE, NUM_LABELS))
    train_all_data_node = tf.constant(train_data)

    # The variables below hold all the trainable weights. They are passed an
    # initial value which will be assigned when when we call:
    # {tf.initialize_all_variables().run()}
    conv1_weights = tf.Variable(
        tf.truncated_normal([5, 5, NUM_CHANNELS, 32],  # 5x5 filter, depth 32.
                            stddev=0.1,
                            seed=SEED))
    conv1_biases = tf.Variable(tf.zeros([32]))
    conv2_weights = tf.Variable(
        tf.truncated_normal([5, 5, 32, 64],
                            stddev=0.1,
                            seed=SEED))
    conv2_biases = tf.Variable(tf.constant(0.1, shape=[64]))
    fc1_weights = tf.Variable(  # fully connected, depth 512.
        tf.truncated_normal([int(IMG_PATCH_SIZE / 4 * IMG_PATCH_SIZE / 4 * 64), 512],
                            stddev=0.1,
                            seed=SEED))
    fc1_biases = tf.Variable(tf.constant(0.1, shape=[512]))
    fc2_weights = tf.Variable(
        tf.truncated_normal([512, NUM_LABELS],
                            stddev=0.1,
                            seed=SEED))
    fc2_biases = tf.Variable(tf.constant(0.1, shape=[NUM_LABELS]))

    # Make an image summary for 4d tensor image with index idx
    def get_image_summary(img, idx=0):
        V = tf.slice(img, (0, 0, 0, idx), (1, -1, -1, 1))
        img_w = img.get_shape().as_list()[1]
        img_h = img.get_shape().as_list()[2]
        min_value = tf.reduce_min(V)
        V = V - min_value
        max_value = tf.reduce_max(V)
        V = V / (max_value*PIXEL_DEPTH)
        V = tf.reshape(V, (img_w, img_h, 1))
        V = tf.transpose(V, (2, 0, 1))
        V = tf.reshape(V, (-1, img_w, img_h, 1))
        return V

    # Make an image summary for 3d tensor image with index idx
    def get_image_summary_3d(img):
        V = tf.slice(img, (0, 0, 0), (1, -1, -1))
        img_w = img.get_shape().as_list()[1]
        img_h = img.get_shape().as_list()[2]
        V = tf.reshape(V, (img_w, img_h, 1))
        V = tf.transpose(V, (2, 0, 1))
        V = tf.reshape(V, (-1, img_w, img_h, 1))
        return V

    # Get prediction for given input image
    def get_prediction(img):
        data = numpy.asarray(img_crop(img, IMG_PATCH_SIZE, IMG_PATCH_SIZE))
        data_node = tf.constant(data)
        output = tf.nn.softmax(model(data_node))
        output_prediction = s.run(output)
        img_prediction = label_to_img(img.shape[0], img.shape[1], IMG_PATCH_SIZE, IMG_PATCH_SIZE, output_prediction)

        return img_prediction

    # Get a concatenation of the prediction and groundtruth for given input file
    def get_prediction_with_groundtruth(filename, image_idx):

        imageid = "satImage_%.3d" % image_idx
        image_filename = filename + imageid + ".png"
        img = mpimg.imread(image_filename)

        img_prediction = get_prediction(img)
        cimg = concatenate_images(img, img_prediction)

        return cimg

    # Get prediction overlaid on the original image for given input file
    def get_prediction_with_overlay(filename, image_idx):

        imageid = "satImage_%.3d" % image_idx
        image_filename = filename + imageid + ".png"
        img = mpimg.imread(image_filename)

        img_prediction = get_prediction(img)
        oimg = make_img_overlay(img, img_prediction)

        return oimg

    # We will replicate the model structure for the training subgraph, as well
    # as the evaluation subgraphs, while sharing the trainable parameters.
    def model(data, train=False):
        """The Model definition."""
        # 2D convolution, with 'SAME' padding (i.e. the output feature map has
        # the same size as the input). Note that {strides} is a 4D array whose
        # shape matches the data layout: [image index, y, x, depth].
        conv = tf.nn.conv2d(data,
                            conv1_weights,
                            strides=[1, 1, 1, 1],
                            padding='SAME')
        # Bias and rectified linear non-linearity.
        relu = tf.nn.relu(tf.nn.bias_add(conv, conv1_biases))
        # Max pooling. The kernel size spec {ksize} also follows the layout of
        # the data. Here we have a pooling window of 2, and a stride of 2.
        pool = tf.nn.max_pool(relu,
                              ksize=[1, 2, 2, 1],
                              strides=[1, 2, 2, 1],
                              padding='SAME')

        conv2 = tf.nn.conv2d(pool,
                             conv2_weights,
                             strides=[1, 1, 1, 1],
                             padding='SAME')
        relu2 = tf.nn.relu(tf.nn.bias_add(conv2, conv2_biases))
        pool2 = tf.nn.max_pool(relu2,
                               ksize=[1, 2, 2, 1],
                               strides=[1, 2, 2, 1],
                               padding='SAME')

        
        # Reshape the feature map cuboid into a 2D matrix to feed it to the
        # fully connected layers.
        pool_shape = pool2.get_shape().as_list()
        reshape = tf.reshape(
            pool2,
            [pool_shape[0], pool_shape[1] * pool_shape[2] * pool_shape[3]])
        # Fully connected layer. Note that the '+' operation automatically
        # broadcasts the biases.
        hidden = tf.nn.relu(tf.matmul(reshape, fc1_weights) + fc1_biases)

        out = tf.matmul(hidden, fc2_weights) + fc2_biases

        if train:
            summary_id = '_0'
            s_data = get_image_summary(data)
            tf.summary.image('summary_data' + summary_id, s_data)
            s_conv = get_image_summary(conv)
            tf.summary.image('summary_conv' + summary_id, s_conv)
            s_pool = get_image_summary(pool)
            tf.summary.image('summary_pool' + summary_id, s_pool)
            s_conv2 = get_image_summary(conv2)
            tf.summary.image('summary_conv2' + summary_id, s_conv2)
            s_pool2 = get_image_summary(pool2)
            tf.summary.image('summary_pool2' + summary_id, s_pool2)
        return out

    # Training computation: logits + cross-entropy loss.
    logits = model(train_data_node, True)  # BATCH_SIZE*NUM_LABELS
    # print 'logits = ' + str(logits.get_shape()) + ' train_labels_node = ' + str(train_labels_node.get_shape())

    loss = tf.reduce_mean(
        tf.nn.softmax_cross_entropy_with_logits_v2(labels=train_labels_node,
                                                   logits=logits))

    tf.summary.scalar('loss', loss)

    all_params_node = [conv1_weights, conv1_biases, conv2_weights, conv2_biases, fc1_weights, fc1_biases, fc2_weights, fc2_biases]
    all_params_names = ['conv1_weights', 'conv1_biases', 'conv2_weights', 'conv2_biases', 'fc1_weights', 'fc1_biases', 'fc2_weights', 'fc2_biases']
    all_grads_node = tf.gradients(loss, all_params_node)
    all_grad_norms_node = []
    for i in range(0, len(all_grads_node)):
        norm_grad_i = tf.global_norm([all_grads_node[i]])
        all_grad_norms_node.append(norm_grad_i)
        tf.summary.scalar(all_params_names[i], norm_grad_i)

    # L2 regularization for the fully connected parameters.
    regularizers = (tf.nn.l2_loss(fc1_weights) + tf.nn.l2_loss(fc1_biases) +
                    tf.nn.l2_loss(fc2_weights) + tf.nn.l2_loss(fc2_biases))
    # Add the regularization term to the loss.
    loss += 5e-4 * regularizers

    batch = tf.Variable(0)
    # Decay once per epoch, using an exponential schedule starting at 0.01.
    learning_rate = tf.train.exponential_decay(
        0.01,                # Base learning rate.
        batch * BATCH_SIZE,  # Current index into the dataset.
        train_size,          # Decay step.
        0.95,                # Decay rate.
        staircase=True)
    # tf.scalar_summary('learning_rate', learning_rate)
    tf.summary.scalar('learning_rate', learning_rate)

    # Use simple momentum for the optimization.
    optimizer = tf.train.MomentumOptimizer(learning_rate,
                                           0.0).minimize(loss,
                                                         global_step=batch)

    # Predictions for the minibatch, validation set and test set.
    train_prediction = tf.nn.softmax(logits)
    # We'll compute them only once in a while by calling their {eval()} method.
    train_all_prediction = tf.nn.softmax(model(train_all_data_node))

    # Add ops to save and restore all the variables.
    saver = tf.train.Saver()

    # Create a local session to run this computation.
    with tf.Session() as s:

        if RESTORE_MODEL:
            # Restore variables from disk.
            saver.restore(s, FLAGS.train_dir + "/model.ckpt")
            print("Model restored.")

        else:
            # Run all the initializers to prepare the trainable parameters.
            tf.global_variables_initializer().run()

            # Build the summary operation based on the TF collection of Summaries.
            summary_op = tf.summary.merge_all()
            summary_writer = tf.summary.FileWriter(FLAGS.train_dir,
                                                   graph=s.graph)

            print('Initialized!')
            # Loop through training steps.
            print('Total number of iterations = ' + str(int(num_epochs * train_size / BATCH_SIZE)))

            training_indices = range(train_size)

            for iepoch in range(num_epochs):

                # Permute training indices
                perm_indices = numpy.random.permutation(training_indices)

                steps_per_epoch = int(train_size / BATCH_SIZE)

                for step in range(steps_per_epoch):

                    offset = (step * BATCH_SIZE) % (train_size - BATCH_SIZE)
                    batch_indices = perm_indices[offset:(offset + BATCH_SIZE)]

                    # Compute the offset of the current minibatch in the data.
                    # Note that we could use better randomization across epochs.
                    batch_data = train_data[batch_indices, :, :, :]
                    batch_labels = train_labels[batch_indices]
                    # This dictionary maps the batch data (as a numpy array) to the
                    # node in the graph is should be fed to.
                    feed_dict = {train_data_node: batch_data,
                                 train_labels_node: batch_labels}

                    if step == 0:
                        summary_str, _, l, lr, predictions = s.run(
                            [summary_op, optimizer, loss, learning_rate, train_prediction],
                            feed_dict=feed_dict)
                        summary_writer.add_summary(summary_str, iepoch * steps_per_epoch)
                        summary_writer.flush()

                        print('Epoch %d' % iepoch)
                        print('Minibatch loss: %.3f, learning rate: %.6f' % (l, lr))
                        print('Minibatch error: %.1f%%' % error_rate(predictions,
                                                                     batch_labels))

                        sys.stdout.flush()
                    else:
                        # Run the graph and fetch some of the nodes.
                        _, l, lr, predictions = s.run(
                            [optimizer, loss, learning_rate, train_prediction],
                            feed_dict=feed_dict)

                # Save the variables to disk.
                save_path = saver.save(s, FLAGS.train_dir + "/model.ckpt")
                print("Model saved in file: %s" % save_path)

        def load_image(infilename):
            data = mpimg.imread(infilename)
            return data

        def binary_to_uint8(img):
            rimg = (img * 255).round().astype(numpy.uint8)
            return rimg
        
        def validate():
            print('validate')
            for img_idx in range(TRAINING_SIZE + 2, 101):
                imageid = "satImage_%.3d" % img_idx
                image_filename = train_data_filename + imageid + ".png"
                img = mpimg.imread(image_filename)

                img_prediction = get_prediction(img)

                Image.fromarray(binary_to_uint8(img_prediction))\
                    .save(train_validation_filename + 'satImage_' + '%.3d'%img_idx + '.png')

            validation_train = extract_labels(train_validation_filename, 100, TRAINING_SIZE + 2)[:,0]
            validation_labels = extract_labels(train_labels_filename, 100, TRAINING_SIZE + 2)[:,0]
            print('Validation F1 Score: ', metrics.f1_score(validation_train, validation_labels))
            print('Validation Accuracy Score: ', metrics.accuracy_score(validation_train, validation_labels))
            
        def create_test_masks():
            print('Creating test masks')
            for img_idx in range(1, TEST_SIZE + 1):
                test_img_dir_i = test_img_dir + 'test_' + str(img_idx) + '/'
                test_files = os.listdir(test_img_dir_i)
                img = load_image(test_img_dir_i + test_files[0])
                predicted_img = get_prediction(img)
                Image.fromarray(binary_to_uint8(predicted_img)).save('predictions/prediction_' + '%.3d' % img_idx + '.png')
            print('Creating masks done')
                          
        validate()
        create_test_masks()
        return 0
        


if __name__ == '__main__':
    tf.app.run()
# Out:
# Loading images
# Loading training/images/satImage_001.png
# Loading training/images/satImage_002.png
# Loading training/images/satImage_003.png
# Loading training/images/satImage_004.png
# Loading training/images/satImage_005.png
# Loading training/images/satImage_006.png
# Loading training/images/satImage_007.png
# Loading training/images/satImage_008.png
# Loading training/images/satImage_009.png
# Loading training/images/satImage_010.png
# Loading training/images/satImage_011.png
# Loading training/images/satImage_012.png
# Loading training/images/satImage_013.png
# Loading training/images/satImage_014.png
# Loading training/images/satImage_015.png
# Loading training/images/satImage_016.png
# Loading training/images/satImage_017.png
# Loading training/images/satImage_018.png
# Loading training/images/satImage_019.png
# Loading training/images/satImage_020.png
# Loading training/images/satImage_021.png
# Loading training/images/satImage_022.png
# Loading training/images/satImage_023.png
# Loading training/images/satImage_024.png
# Loading training/images/satImage_025.png
# Loading training/images/satImage_026.png
# Loading training/images/satImage_027.png
# Loading training/images/satImage_028.png
# Loading training/images/satImage_029.png
# Loading training/images/satImage_030.png
# Loading training/images/satImage_031.png
# Loading training/images/satImage_032.png
# Loading training/images/satImage_033.png
# Loading training/images/satImage_034.png
# Loading training/images/satImage_035.png
# Loading training/images/satImage_036.png
# Loading training/images/satImage_037.png
# Loading training/images/satImage_038.png
# Loading training/images/satImage_039.png
# Loading training/images/satImage_040.png
# Loading training/images/satImage_041.png
# Loading training/images/satImage_042.png
# Loading training/images/satImage_043.png
# Loading training/images/satImage_044.png
# Loading training/images/satImage_045.png
# Loading training/images/satImage_046.png
# Loading training/images/satImage_047.png
# Loading training/images/satImage_048.png
# Loading training/images/satImage_049.png
# Loading training/images/satImage_050.png
# Loading training/images/satImage_051.png
# Loading training/images/satImage_052.png
# Loading training/images/satImage_053.png
# Loading training/images/satImage_054.png
# Loading training/images/satImage_055.png
# Loading training/images/satImage_056.png
# Loading training/images/satImage_057.png
# Loading training/images/satImage_058.png
# Loading training/images/satImage_059.png
# Loading training/images/satImage_060.png
# Loading training/images/satImage_061.png
# Loading training/images/satImage_062.png
# Loading training/images/satImage_063.png
# Loading training/images/satImage_064.png
# Loading training/images/satImage_065.png
# Loading training/images/satImage_066.png
# Loading training/images/satImage_067.png
# Loading training/images/satImage_068.png
# Loading training/images/satImage_069.png
# Loading training/images/satImage_070.png
# Loading training/images/satImage_071.png
# Loading training/images/satImage_072.png
# Loading training/images/satImage_073.png
# Loading training/images/satImage_074.png
# Loading training/images/satImage_075.png
# Loading training/images/satImage_076.png
# Loading training/images/satImage_077.png
# Loading training/images/satImage_078.png
# Loading training/images/satImage_079.png
# Loading training/images/satImage_080.png
# Number of data points per class: c0 = 37115 c1 = 12885
# Balancing training data...
# 25770
# (50000, 16, 16, 3)
# Number of data points per class: c0 = 12885 c1 = 12885
# Initialized!
# Total number of iterations = 161062
# Epoch 0
# Minibatch loss: 2.421, learning rate: 0.010000
# Minibatch error: 56.2%
# Model saved in file: /tmp/segment_aerial_images/model.ckpt
# Epoch 1
# Minibatch loss: 1.499, learning rate: 0.010000
# Minibatch error: 25.0%
# Model saved in file: /tmp/segment_aerial_images/model.ckpt
# Epoch 2
# Minibatch loss: 1.556, learning rate: 0.009500
# Minibatch error: 37.5%
# Model saved in file: /tmp/segment_aerial_images/model.ckpt
# Epoch 3
# Minibatch loss: 1.501, learning rate: 0.009025
# Minibatch error: 31.2%
# Model saved in file: /tmp/segment_aerial_images/model.ckpt
# Epoch 4
# Minibatch loss: 1.468, learning rate: 0.008574
# Minibatch error: 25.0%
# Model saved in file: /tmp/segment_aerial_images/model.ckpt
# Epoch 5
# Minibatch loss: 1.479, learning rate: 0.008145
# Minibatch error: 12.5%
# Model saved in file: /tmp/segment_aerial_images/model.ckpt
# Epoch 6
# Minibatch loss: 1.288, learning rate: 0.007738
# Minibatch error: 6.2%
# Model saved in file: /tmp/segment_aerial_images/model.ckpt
# Epoch 7
# Minibatch loss: 1.407, learning rate: 0.007351
# Minibatch error: 18.8%
# Model saved in file: /tmp/segment_aerial_images/model.ckpt
# Epoch 8
# Minibatch loss: 1.367, learning rate: 0.006983
# Minibatch error: 18.8%
# Model saved in file: /tmp/segment_aerial_images/model.ckpt
# Epoch 9
# Minibatch loss: 1.597, learning rate: 0.006634
# Minibatch error: 25.0%
# Model saved in file: /tmp/segment_aerial_images/model.ckpt
# Epoch 10
# Minibatch loss: 1.344, learning rate: 0.006302
# Minibatch error: 25.0%
# Model saved in file: /tmp/segment_aerial_images/model.ckpt
# Epoch 11
# Minibatch loss: 1.456, learning rate: 0.005987
# Minibatch error: 25.0%
# Model saved in file: /tmp/segment_aerial_images/model.ckpt
# Epoch 12
# Minibatch loss: 1.382, learning rate: 0.005688
# Minibatch error: 25.0%
# Model saved in file: /tmp/segment_aerial_images/model.ckpt
# Epoch 13
# Minibatch loss: 1.102, learning rate: 0.005404
# Minibatch error: 6.2%
# Model saved in file: /tmp/segment_aerial_images/model.ckpt
# Epoch 14
# Minibatch loss: 1.475, learning rate: 0.005133
# Minibatch error: 25.0%
# Model saved in file: /tmp/segment_aerial_images/model.ckpt
# Epoch 15
# Minibatch loss: 1.309, learning rate: 0.004877
# Minibatch error: 18.8%
# Model saved in file: /tmp/segment_aerial_images/model.ckpt
# Epoch 16
# Minibatch loss: 1.484, learning rate: 0.004633
# Minibatch error: 25.0%
# Model saved in file: /tmp/segment_aerial_images/model.ckpt
# Epoch 17
# Minibatch loss: 1.081, learning rate: 0.004401
# Minibatch error: 12.5%
# Model saved in file: /tmp/segment_aerial_images/model.ckpt
# Epoch 18
# Minibatch loss: 1.127, learning rate: 0.004181
# Minibatch error: 12.5%
# Model saved in file: /tmp/segment_aerial_images/model.ckpt
# Epoch 19
# Minibatch loss: 1.033, learning rate: 0.003972
# Minibatch error: 6.2%
# Model saved in file: /tmp/segment_aerial_images/model.ckpt
# Epoch 20
# Minibatch loss: 1.112, learning rate: 0.003774
# Minibatch error: 18.8%
# Model saved in file: /tmp/segment_aerial_images/model.ckpt
# Epoch 21
# Minibatch loss: 1.274, learning rate: 0.003585
# Minibatch error: 12.5%
# Model saved in file: /tmp/segment_aerial_images/model.ckpt
# Epoch 22
# Minibatch loss: 1.059, learning rate: 0.003406
# Minibatch error: 12.5%
# Model saved in file: /tmp/segment_aerial_images/model.ckpt
# Epoch 23
# Minibatch loss: 1.270, learning rate: 0.003235
# Minibatch error: 25.0%
# Model saved in file: /tmp/segment_aerial_images/model.ckpt
# Epoch 24
# Minibatch loss: 1.314, learning rate: 0.003074
# Minibatch error: 18.8%
# Model saved in file: /tmp/segment_aerial_images/model.ckpt
# Epoch 25
# Minibatch loss: 1.068, learning rate: 0.002920
# Minibatch error: 18.8%
# Model saved in file: /tmp/segment_aerial_images/model.ckpt
# Epoch 26
# Minibatch loss: 1.136, learning rate: 0.002774
# Minibatch error: 12.5%
# Model saved in file: /tmp/segment_aerial_images/model.ckpt
# Epoch 27
# Minibatch loss: 1.225, learning rate: 0.002635
# Minibatch error: 18.8%
# Model saved in file: /tmp/segment_aerial_images/model.ckpt
# Epoch 28
# Minibatch loss: 1.121, learning rate: 0.002503
# Minibatch error: 12.5%
# Model saved in file: /tmp/segment_aerial_images/model.ckpt
# Epoch 29
# Minibatch loss: 1.220, learning rate: 0.002378
# Minibatch error: 18.8%
# Model saved in file: /tmp/segment_aerial_images/model.ckpt
# Epoch 30
# Minibatch loss: 1.076, learning rate: 0.002259
# Minibatch error: 12.5%
# Model saved in file: /tmp/segment_aerial_images/model.ckpt
# Epoch 31
# Minibatch loss: 0.923, learning rate: 0.002146
# Minibatch error: 0.0%
# Model saved in file: /tmp/segment_aerial_images/model.ckpt
# Epoch 32
# Minibatch loss: 1.000, learning rate: 0.002039
# Minibatch error: 12.5%
# Model saved in file: /tmp/segment_aerial_images/model.ckpt
# Epoch 33
# Minibatch loss: 0.953, learning rate: 0.001937
# Minibatch error: 0.0%
# Model saved in file: /tmp/segment_aerial_images/model.ckpt
# Epoch 34
# Minibatch loss: 1.010, learning rate: 0.001840
# Minibatch error: 6.2%
# Model saved in file: /tmp/segment_aerial_images/model.ckpt
# Epoch 35
# Minibatch loss: 1.026, learning rate: 0.001748
# Minibatch error: 12.5%
# Model saved in file: /tmp/segment_aerial_images/model.ckpt
# Epoch 36
# Minibatch loss: 0.917, learning rate: 0.001661
# Minibatch error: 6.2%
# Model saved in file: /tmp/segment_aerial_images/model.ckpt
# Epoch 37
# Minibatch loss: 0.989, learning rate: 0.001578
# Minibatch error: 6.2%
# Model saved in file: /tmp/segment_aerial_images/model.ckpt
# Epoch 38
# Minibatch loss: 0.965, learning rate: 0.001499
# Minibatch error: 6.2%
# Model saved in file: /tmp/segment_aerial_images/model.ckpt
# Epoch 39
# Minibatch loss: 0.902, learning rate: 0.001424
# Minibatch error: 0.0%
# Model saved in file: /tmp/segment_aerial_images/model.ckpt
# Epoch 40
# Minibatch loss: 1.099, learning rate: 0.001353
# Minibatch error: 18.8%
# Model saved in file: /tmp/segment_aerial_images/model.ckpt
# Epoch 41
# Minibatch loss: 1.051, learning rate: 0.001285
# Minibatch error: 25.0%
# Model saved in file: /tmp/segment_aerial_images/model.ckpt
# Epoch 42
# Minibatch loss: 1.077, learning rate: 0.001221
# Minibatch error: 12.5%
# Model saved in file: /tmp/segment_aerial_images/model.ckpt
# Epoch 43
# Minibatch loss: 0.892, learning rate: 0.001160
# Minibatch error: 6.2%
# Model saved in file: /tmp/segment_aerial_images/model.ckpt
# Epoch 44
# Minibatch loss: 1.010, learning rate: 0.001102
# Minibatch error: 12.5%
# Model saved in file: /tmp/segment_aerial_images/model.ckpt
# Epoch 45
# Minibatch loss: 0.910, learning rate: 0.001047
# Minibatch error: 0.0%
# Model saved in file: /tmp/segment_aerial_images/model.ckpt
# Epoch 46
# Minibatch loss: 0.990, learning rate: 0.000994
# Minibatch error: 12.5%
# Model saved in file: /tmp/segment_aerial_images/model.ckpt
# Epoch 47
# Minibatch loss: 1.014, learning rate: 0.000945
# Minibatch error: 6.2%
# Model saved in file: /tmp/segment_aerial_images/model.ckpt
# Epoch 48
# Minibatch loss: 0.829, learning rate: 0.000897
# Minibatch error: 0.0%
# Model saved in file: /tmp/segment_aerial_images/model.ckpt
# Epoch 49
# Minibatch loss: 0.838, learning rate: 0.000853
# Minibatch error: 0.0%
# Model saved in file: /tmp/segment_aerial_images/model.ckpt
# Epoch 50
# Minibatch loss: 1.300, learning rate: 0.000810
# Minibatch error: 25.0%
# Model saved in file: /tmp/segment_aerial_images/model.ckpt
# Epoch 51
# Minibatch loss: 0.887, learning rate: 0.000769
# Minibatch error: 0.0%
# Model saved in file: /tmp/segment_aerial_images/model.ckpt
# Epoch 52
# Minibatch loss: 0.864, learning rate: 0.000731
# Minibatch error: 0.0%
# Model saved in file: /tmp/segment_aerial_images/model.ckpt
# Epoch 53
# Minibatch loss: 0.937, learning rate: 0.000694
# Minibatch error: 6.2%
# Model saved in file: /tmp/segment_aerial_images/model.ckpt
# Epoch 54
# Minibatch loss: 0.972, learning rate: 0.000660
# Minibatch error: 12.5%
# Model saved in file: /tmp/segment_aerial_images/model.ckpt
# Epoch 55
# Minibatch loss: 0.876, learning rate: 0.000627
# Minibatch error: 0.0%
# Model saved in file: /tmp/segment_aerial_images/model.ckpt
# Epoch 56
# Minibatch loss: 0.853, learning rate: 0.000595
# Minibatch error: 6.2%
# Model saved in file: /tmp/segment_aerial_images/model.ckpt
# Epoch 57
# Minibatch loss: 1.202, learning rate: 0.000566
# Minibatch error: 12.5%
# Model saved in file: /tmp/segment_aerial_images/model.ckpt
# Epoch 58
# Minibatch loss: 0.967, learning rate: 0.000537
# Minibatch error: 6.2%
# Model saved in file: /tmp/segment_aerial_images/model.ckpt
# Epoch 59
# Minibatch loss: 0.850, learning rate: 0.000510
# Minibatch error: 6.2%
# Model saved in file: /tmp/segment_aerial_images/model.ckpt
# Epoch 60
# Minibatch loss: 0.853, learning rate: 0.000485
# Minibatch error: 0.0%
# Model saved in file: /tmp/segment_aerial_images/model.ckpt
# Epoch 61
# Minibatch loss: 0.839, learning rate: 0.000461
# Minibatch error: 0.0%
# Model saved in file: /tmp/segment_aerial_images/model.ckpt
# Epoch 62
# Minibatch loss: 0.883, learning rate: 0.000438
# Minibatch error: 0.0%
# Model saved in file: /tmp/segment_aerial_images/model.ckpt
# Epoch 63
# Minibatch loss: 0.895, learning rate: 0.000416
# Minibatch error: 6.2%
# Model saved in file: /tmp/segment_aerial_images/model.ckpt
# Epoch 64
# Minibatch loss: 0.945, learning rate: 0.000395
# Minibatch error: 12.5%
# Model saved in file: /tmp/segment_aerial_images/model.ckpt
# Epoch 65
# Minibatch loss: 0.907, learning rate: 0.000375
# Minibatch error: 6.2%
# Model saved in file: /tmp/segment_aerial_images/model.ckpt
# Epoch 66
# Minibatch loss: 0.875, learning rate: 0.000356
# Minibatch error: 0.0%
# Model saved in file: /tmp/segment_aerial_images/model.ckpt
# Epoch 67
# Minibatch loss: 0.852, learning rate: 0.000339
# Minibatch error: 0.0%
# Model saved in file: /tmp/segment_aerial_images/model.ckpt
# Epoch 68
# Minibatch loss: 0.939, learning rate: 0.000322
# Minibatch error: 6.2%
# Model saved in file: /tmp/segment_aerial_images/model.ckpt
# Epoch 69
# Minibatch loss: 0.972, learning rate: 0.000306
# Minibatch error: 12.5%
# Model saved in file: /tmp/segment_aerial_images/model.ckpt
# Epoch 70
# Minibatch loss: 0.948, learning rate: 0.000290
# Minibatch error: 6.2%
# Model saved in file: /tmp/segment_aerial_images/model.ckpt
# Epoch 71
# Minibatch loss: 1.015, learning rate: 0.000276
# Minibatch error: 25.0%
# Model saved in file: /tmp/segment_aerial_images/model.ckpt
# Epoch 72
# Minibatch loss: 0.958, learning rate: 0.000262
# Minibatch error: 12.5%
# Model saved in file: /tmp/segment_aerial_images/model.ckpt
# Epoch 73
# Minibatch loss: 0.932, learning rate: 0.000249
# Minibatch error: 6.2%
# Model saved in file: /tmp/segment_aerial_images/model.ckpt
# Epoch 74
# Minibatch loss: 1.178, learning rate: 0.000236
# Minibatch error: 18.8%
# Model saved in file: /tmp/segment_aerial_images/model.ckpt
# Epoch 75
# Minibatch loss: 0.883, learning rate: 0.000225
# Minibatch error: 0.0%
# Model saved in file: /tmp/segment_aerial_images/model.ckpt
# Epoch 76
# Minibatch loss: 1.017, learning rate: 0.000213
# Minibatch error: 6.2%
# Model saved in file: /tmp/segment_aerial_images/model.ckpt
# Epoch 77
# Minibatch loss: 0.965, learning rate: 0.000203
# Minibatch error: 6.2%
# Model saved in file: /tmp/segment_aerial_images/model.ckpt
# Epoch 78
# Minibatch loss: 0.895, learning rate: 0.000193
# Minibatch error: 0.0%
# Model saved in file: /tmp/segment_aerial_images/model.ckpt
# Epoch 79
# Minibatch loss: 1.034, learning rate: 0.000183
# Minibatch error: 12.5%
# Model saved in file: /tmp/segment_aerial_images/model.ckpt
# Epoch 80
# Minibatch loss: 0.986, learning rate: 0.000174
# Minibatch error: 12.5%
# Model saved in file: /tmp/segment_aerial_images/model.ckpt
# Epoch 81
# Minibatch loss: 0.837, learning rate: 0.000165
# Minibatch error: 0.0%
# Model saved in file: /tmp/segment_aerial_images/model.ckpt
# Epoch 82
# Minibatch loss: 0.925, learning rate: 0.000157
# Minibatch error: 0.0%
# Model saved in file: /tmp/segment_aerial_images/model.ckpt
# Epoch 83
# Minibatch loss: 0.977, learning rate: 0.000149
# Minibatch error: 6.2%
# Model saved in file: /tmp/segment_aerial_images/model.ckpt
# Epoch 84
# Minibatch loss: 1.089, learning rate: 0.000142
# Minibatch error: 12.5%
# Model saved in file: /tmp/segment_aerial_images/model.ckpt
# Epoch 85
# Minibatch loss: 0.896, learning rate: 0.000135
# Minibatch error: 6.2%
# Model saved in file: /tmp/segment_aerial_images/model.ckpt
# Epoch 86
# Minibatch loss: 0.883, learning rate: 0.000128
# Minibatch error: 0.0%
# Model saved in file: /tmp/segment_aerial_images/model.ckpt
# Epoch 87
# Minibatch loss: 0.810, learning rate: 0.000121
# Minibatch error: 0.0%
# Model saved in file: /tmp/segment_aerial_images/model.ckpt
# Epoch 88
# Minibatch loss: 1.049, learning rate: 0.000115
# Minibatch error: 6.2%
# Model saved in file: /tmp/segment_aerial_images/model.ckpt
# Epoch 89
# Minibatch loss: 0.855, learning rate: 0.000110
# Minibatch error: 6.2%
# Model saved in file: /tmp/segment_aerial_images/model.ckpt
# Epoch 90
# Minibatch loss: 0.834, learning rate: 0.000104
# Minibatch error: 0.0%
# Model saved in file: /tmp/segment_aerial_images/model.ckpt
# Epoch 91
# Minibatch loss: 1.112, learning rate: 0.000099
# Minibatch error: 12.5%
# Model saved in file: /tmp/segment_aerial_images/model.ckpt
# Epoch 92
# Minibatch loss: 0.992, learning rate: 0.000094
# Minibatch error: 12.5%
# Model saved in file: /tmp/segment_aerial_images/model.ckpt
# Epoch 93
# Minibatch loss: 0.978, learning rate: 0.000089
# Minibatch error: 6.2%
# Model saved in file: /tmp/segment_aerial_images/model.ckpt
# Epoch 94
# Minibatch loss: 1.025, learning rate: 0.000085
# Minibatch error: 18.8%
# Model saved in file: /tmp/segment_aerial_images/model.ckpt
# Epoch 95
# Minibatch loss: 0.840, learning rate: 0.000081
# Minibatch error: 0.0%
# Model saved in file: /tmp/segment_aerial_images/model.ckpt
# Epoch 96
# Minibatch loss: 0.948, learning rate: 0.000077
# Minibatch error: 12.5%
# Model saved in file: /tmp/segment_aerial_images/model.ckpt
# Epoch 97
# Minibatch loss: 0.801, learning rate: 0.000073
# Minibatch error: 0.0%
# Model saved in file: /tmp/segment_aerial_images/model.ckpt
# Epoch 98
# Minibatch loss: 0.782, learning rate: 0.000069
# Minibatch error: 0.0%
# Model saved in file: /tmp/segment_aerial_images/model.ckpt
# Epoch 99
# Minibatch loss: 0.938, learning rate: 0.000066
# Minibatch error: 6.2%
# Model saved in file: /tmp/segment_aerial_images/model.ckpt
# validate
# Validation F1 Score:  0.811764705882
# Validation Accuracy Score:  0.749389473684
# Creating test masks
# Creating masks done
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 0
# /home/sabrina/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2971: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)
